# %%
import os
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
# Import Data Set

# %%
os.getcwd()
# Out:
# 'C:\\Users\\riaz khan'

# %%
df = pd.read_csv("C:\\Users\\riaz khan\\Data_set.csv", encoding='latin-1')

import chardet

with open("C:\\Users\\riaz khan\\Data_set.csv", 'rb') as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    encoding = result['encoding']

df = pd.read_csv("C:\\Users\\riaz khan\\Data_set.csv", encoding=encoding)
# !pip install chardet

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.shape
df.drop('ORDERNUMBER',axis=1)
df.drop('ORDERDATE', asix = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16052\3940565211.py in <module>
# ----> 1 df.shape
#       2 df.drop('ORDERNUMBER',axis=1)
#       3 df.drop('ORDERDATE', asix = 1)
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16052\3771845804.py in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe(include=np.number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16052\2836138448.py in <module>
# ----> 1 df.describe(include=np.number)
#
# NameError: name 'df' is not defined

# %%
df.describe(include=np.object)
# Out:
# C:\Users\riaz khan\AppData\Local\Temp\ipykernel_21928\3211851552.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df.describe(include=np.object)
#               ORDERDATE   STATUS   PRODUCTLINE PRODUCTCODE  \
# count              2823     2823          2823        2823
# unique              252        6             7         109
# top     11/14/2003 0:00  Shipped  Classic Cars    S18_3232
# freq                 38     2617           967          52
#
#                  CUSTOMERNAME           PHONE        ADDRESSLINE1  \
# count                    2823            2823                2823
# unique                     92              91                  92
# top     Euro Shopping Channel  (91) 555 94 44  C/ Moralzarzal, 86
# ...

# %%
df = df.drop('ORDERNUMBER', axis= 1)

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  QTR_ID  \
# 0               30      95.70                2  2871.00  Shipped       1
# 1               34      81.35                5  2765.90  Shipped       2
# 2               41      94.74                2  3884.34  Shipped       3
# 3               45      83.26                6  3746.70  Shipped       3
# 4               49     100.00               14  5205.27  Shipped       4
#
#    MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  ...                   ADDRESSLINE1  \
# 0         2     2003  Motorcycles    95  ...        897 Long Airport Avenue
# 1         5     2003  Motorcycles    95  ...             59 rue de l'Abbaye
# 2         7     2003  Motorcycles    95  ...  27 rue du Colonel Pierre Avia
# 3         8     2003  Motorcycles    95  ...             78934 Hillside Dr.
# 4        10     2003  Motorcycles    95  ...                7734 Strong St.
#
#   ADDRESSLINE2           CITY STATE POSTALCODE COUNTRY TERRITORY  \
# ...

# %%
df= pf.drop('ADDRESSLINE1', axis =1)

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...        2125557818
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...        26.47.1555
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...  +33 1 46 62 7555
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...        6265557265
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...        6505551386
#
#    ADDRESSLINE2           CITY STATE POSTALCODE COUNTRY TERRITORY  \
# ...

# %%
df.describe(include=np.object)
# Out:
# C:\Users\riaz khan\AppData\Local\Temp\ipykernel_21928\3211851552.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df.describe(include=np.object)
#               ORDERDATE   STATUS   PRODUCTLINE PRODUCTCODE  \
# count              2823     2823          2823        2823
# unique              252        6             7         109
# top     11/14/2003 0:00  Shipped  Classic Cars    S18_3232
# freq                 38     2617           967          52
#
#                  CUSTOMERNAME           PHONE ADDRESSLINE2    CITY STATE  \
# count                    2823            2823          302    2823  1337
# unique                     92              91            9      73    16
# ...

# %%
#Data Cleaning

# %%
df = df.drop(['PHONE','ADDRESSLINE2','POSTALCODE'], axis =1 )

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...    S10_1678
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...    S10_1678
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...    S10_1678
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...    S10_1678
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...    S10_1678
#
#                CUSTOMERNAME                   ADDRESSLINE1           CITY  \
# ...

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  PRODUCTCODE  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# ADDRESSLINE1           0
# CITY                   0
# STATE               1486
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.isnull().sum()/len(df)
# Out:
# ORDERNUMBER         0.000000
# QUANTITYORDERED     0.000000
# PRICEEACH           0.000000
# ORDERLINENUMBER     0.000000
# SALES               0.000000
# ORDERDATE           0.000000
# STATUS              0.000000
# QTR_ID              0.000000
# MONTH_ID            0.000000
# YEAR_ID             0.000000
# PRODUCTLINE         0.000000
# MSRP                0.000000
# PRODUCTCODE         0.000000
# CUSTOMERNAME        0.000000
# ADDRESSLINE1        0.000000
# CITY                0.000000
# STATE               0.526390
# COUNTRY             0.000000
# TERRITORY           0.380446
# CONTACTLASTNAME     0.000000
# CONTACTFIRSTNAME    0.000000
# DEALSIZE            0.000000
# dtype: float64

# %%
df['QUANTITYORDERED'].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['SALES'].plot(kind="kde")
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       5205.27
#          ...
# 2818    2244.40
# 2819    3978.51
# 2820    5417.57
# 2821    2116.16
# 2822    3079.44
# Name: SALES, Length: 2823, dtype: float64

# %%
print(f"skewness of QUANTITYORDERED is ", df['QUANTITYORDERED'].skew())
print(f"skewness of SALES is ", df['SALES'].skew()),]
# Out:
#   File "C:\Users\riaz khan\AppData\Local\Temp\ipykernel_16052\2950183184.py", line 2
#     print(f"skewness of SALES is ", df['SALES'].skew()),plot(kind="kde"]
#                                                                        ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
from sklearn.preprocessing import LabelEncoder

# Encode categorical variables
label_encoder = LabelEncoder()
df['STATUS'] = label_encoder.fit_transform(df['STATUS'])
df['SALES'] = label_encoder.fit_transform(df['SALES'])

# %%
df.drop("PRICEEACH", axis=1, inplace=True)

# %%
pf
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# # Step 4: Split the Data into Training and Testing Sets

# Next, we'll split the dataset into training and testing sets to evaluate the performance of our models.

# %%
x = df.drop('STATUS', axis = 1)
y = df['QUANTITYORDERED']

# %%
x
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES        ORDERDATE  \
# 0           10107               30                2  2871.00   2/24/2003 0:00
# 1           10121               34                5  2765.90    5/7/2003 0:00
# 2           10134               41                2  3884.34    7/1/2003 0:00
# 3           10145               45                6  3746.70   8/25/2003 0:00
# 4           10159               49               14  5205.27  10/10/2003 0:00
# ...           ...              ...              ...      ...              ...
# 2818        10350               20               15  2244.40   12/2/2004 0:00
# 2819        10373               29                1  3978.51   1/31/2005 0:00
# 2820        10386               43                4  5417.57    3/1/2005 0:00
# 2821        10397               34                1  2116.16   3/28/2005 0:00
# 2822        10414               47                9  3079.44    5/6/2005 0:00
#
# ...

# %%
y
# Out:
# 0       30
# 1       34
# 2       41
# 3       45
# 4       49
#         ..
# 2818    20
# 2819    29
# 2820    43
# 2821    34
# 2822    47
# Name: QUANTITYORDERED, Length: 2823, dtype: int64

# %%
df.drop('ORDERDATE', axis=1)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES    STATUS  \
# 0           10107               30                2  2871.00   Shipped
# 1           10121               34                5  2765.90   Shipped
# 2           10134               41                2  3884.34   Shipped
# 3           10145               45                6  3746.70   Shipped
# 4           10159               49               14  5205.27   Shipped
# ...           ...              ...              ...      ...       ...
# 2818        10350               20               15  2244.40   Shipped
# 2819        10373               29                1  3978.51   Shipped
# 2820        10386               43                4  5417.57  Resolved
# 2821        10397               34                1  2116.16   Shipped
# 2822        10414               47                9  3079.44   On Hold
#
#       QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  ...  \
# 0          1         2     2003  Motorcycles    95  ...
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test ,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16052\2292152434.py in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 logistic_regression = LogisticRegression()
# ----> 3 logistic_regression.fit(x_train,y_train)
#
# E:\Apps\New folder\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1506             _dtype = [np.float64, np.float32]
#    1507
# -> 1508         X, y = self._validate_data(
#    1509             X,
#    1510             y,
#
# E:\Apps\New folder\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

# Logistic Regression Classifier
logistic_regression = LogisticRegression()
logistic_regression.fit(A_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16052\710634773.py in <module>
#       3 # Logistic Regression Classifier
#       4 logistic_regression = LogisticRegression()
# ----> 5 logistic_regression.fit(A_train, y_train)
#
# NameError: name 'A_train' is not defined
